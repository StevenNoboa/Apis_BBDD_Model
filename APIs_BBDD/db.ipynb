# %%
import pandas as pd
import sqlite3

# %%
connection = sqlite3.connect("books.db")
crsr = connection.cursor()

# %%
def sql_query(query):
    crsr.execute(query)
    ans = crsr.fetchall()
    names = [description[0] for description in crsr.description]

    return pd.DataFrame(ans,columns=names)

# %%
res = crsr.execute("SELECT name FROM sqlite_master WHERE type='table'")
for name in res:
    print(name[0])
# Out:
# books

# %%
query = "SELECT * FROM books;"

result_df = sql_query(query)
result_df
# Out:
#       id  published              author  \
# 0   None       2014         Ann Leckie
# 1   None       2013         John Scalzi
# 2   None       2012           Jo Walton
# 3   None       2011       Connie Willis
# 4   None       2010    Paolo Bacigalupi
# ..   ...        ...                 ...
# 62  None       1954        Ray Bradbury
# 63  None       1953       Alfred Bester
# 64  None       1951  Robert A. Heinlein
# 65  None       1946        Isaac Asimov
# 66  None       1939         T. H. White
#
#                                                 title  \
# 0                                   Ancillary Justice
# 1                                           Redshirts
# 2                                        Among Others
# 3             Blackout, All Clear (Vol. 2 - Blackout)
# 4                                     The Windup Girl
# ..                                                ...
# 62                                     Fahrenheit 451
# 63                                 The Demolished Man
# 64                                  Farmer in the Sky
# 65                                           The Mule
# 66  The Sword in the Stone (Part 1 of The Once and...
#
#                                        first_sentence
# 0   The body lay naked and facedown, a deathly gra...
# 1   From the top of the large boulder he sat on, E...
# 2   The Phurnacite factory in Abercwmboi killed al...
# 3   By noon Michael and Merope still hadn’t return...
# 4                  “No! I don’t want the mangosteen.”
# ..                                                ...
# 62                         It was a pleasure to burn.
# 63                                         Explosion!
# 64  Our troop had been up in the High Sierras that...
# 65  Bel Riose traveled without escort, which is no...
# 66                                              ender
#
# [67 rows x 5 columns]
